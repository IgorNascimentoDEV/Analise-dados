# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorNascimentoDEV/Analise-dados/blob/main/atividade08_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Atividade Lab 08/09**
# Para a atividade em questão irei realizar uma análise das 5 séries mais assistidas da Netflix em inglês.
#
# Ref: (https://www.mundoconectado.com.br/cultura/netflix-divulga-filmes-e-series-com-mais-visualizacoes-veja-lista-completa/
# )

# %%
import pandas as pd

dados_series = {
    'Wandinha': 252100000,
    'Stranger Things': 140700000,
    'Dahmer: Um Canibal Americano': 115600000,
    'Bridgerton': 113300000,
    'O Gambito da Rainha': 112800000
}

serie_visualizacoes = pd.Series(dados_series)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       3 dados_series = {
#       4     'Wandinha': 252100000,
#       5     'Stranger Things': 140700000,
#    (...)
#       8     'O Gambito da Rainha': 112800000
#       9 }
#      11 serie_visualizacoes = pd.Series(dados_series)
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# **Gráficos de Barras**

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn')

serie_visualizacoes.plot(kind='bar', color=['blue', 'green'])
plt.title('SÉRIES MAIS VISTAS EM INGLÊS')
plt.xlabel('TÍTULO')
plt.ylabel('VISUALIZAÇÕES')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.style.use('seaborn')
#       5 serie_visualizacoes.plot(kind='bar', color=['blue', 'green'])
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
plt.style.use('seaborn')

serie_visualizacoes.plot(kind='barh', color='skyblue')
plt.title('Séries Mais Vistas em Inglês')
plt.xlabel('Visualizações')
plt.ylabel('Título')

plt.show()
# Out:
# <ipython-input-6-45b3949691ec>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# **Gráfico de Pizza**
#
# Neste gráfico, você pode observar como as visualizações estão distribuídas entre diferentes séries da Netflix. As conclusões possíveis são:
#
# Identificar quais séries têm uma fatia maior do total de visualizações.
# Isso ajuda a destacar as séries mais populares.
#
# Compreender a participação relativa de cada série nas visualizações totais.
#
# Observar se algumas séries dominam as visualizações ou se a distribuição é mais equilibrada.

# %%
labels = serie_visualizacoes.index
sizes = serie_visualizacoes.values

plt.style.use('seaborn')

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição de Visualizações por Série')
plt.axis('equal')


plt.show()
# Out:
# <ipython-input-5-a894d7f81c13>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
